# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('ipl_2023_dataset.csv')

# %%
data
# Out:
#      Unnamed: 0        Player Name           Type  Price Cr  \
# 0             0        Ben Stokes     All-Rounder     16.25
# 1             1   Ravindra Jadeja     All-Rounder     16.00
# 2             2     Deepak Chahar          Bowler     14.00
# 3             3          MS Dhoni   Wicket-Keeper     12.00
# 4             4         Moeen Ali     All-Rounder      8.00
# ..          ...                ...            ...       ...
# 563         563        Dhruv Patel    All-Rounder       NaN
# 564         564    Jack Prestwidge    All-Rounder       NaN
# 565         565     Aditya Sarvate    All-Rounder       NaN
# 566         566      Sagar Solanki    All-Rounder       NaN
# 567         567  Prenelan Subrayen    All-Rounder       NaN
#
#                     Team
# 0    Chennai Super Kings
# 1    Chennai Super Kings
# 2    Chennai Super Kings
# 3    Chennai Super Kings
# 4    Chennai Super Kings
# ..                   ...
# 563               Unsold
# 564               Unsold
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   568 non-null    int64
#  1   Player Name  568 non-null    object
#  2   Type         568 non-null    object
#  3   Price Cr     243 non-null    float64
#  4   Team         568 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 22.3+ KB

# %%
data.head()
# Out:
#    Unnamed: 0       Player Name           Type  Price Cr                 Team
# 0           0       Ben Stokes     All-Rounder     16.25  Chennai Super Kings
# 1           1  Ravindra Jadeja     All-Rounder     16.00  Chennai Super Kings
# 2           2    Deepak Chahar          Bowler     14.00  Chennai Super Kings
# 3           3         MS Dhoni   Wicket-Keeper     12.00  Chennai Super Kings
# 4           4        Moeen Ali     All-Rounder      8.00  Chennai Super Kings

# %%
data.isnull().sum()
# Out:
# Unnamed: 0       0
# Player Name      0
# Type             0
# Price Cr       325
# Team             0
# dtype: int64

# %% [raw]
# # lets plot the bar chart

# %%
data = data[data['Team'] != 'Unsold']

# %%
plt.figure(figsize = (16,8))
sns.barplot(x = data['Team'].values  ,  y = data['Team'].keys()) 
plt.title('Amount Spent  By Each Team', fontsize = 18, fontweight = 'bold')
plt.xlabel('Team Names', fontsize = 16, fontweight = 'bold')
plt.ylabel('Price', fontsize = 16,fontweight = 'bold')
plt.xticks(rotation = 30)
plt.show()

# %%
team_counts = data['Team'].value_counts()
explode = [0.2,0,0.2,0,0.2,0,0.2,0,0.2] 
plt.pie(team_counts, labels = team_counts.index , autopct ='%1.1f%%', explode = explode)
plt.title('[Distribution Of Teams]', fontsize = 22)
plt.show()

# %%
type_values = data['Type'].value_counts().values
type_keys = data['Type'].value_counts().keys()

# %%
plt.pie(type_values, labels = type_keys , autopct = "%.0f%%", wedgeprops = {"linewidth": 1, "edgecolor": "white"})
plt.figure(figsize = (8,8))
plt.show()

# %%
expensive_cricketers = data.sort_values(by = 'Price Cr', ascending = False).head(10)

# %%
plt.figure(figsize = (18,8))
sns.barplot(x = 'Player Name', y = 'Price Cr', data = expensive_cricketers)
plt.xlabel('Player Name', fontsize = 16, fontweight = 'bold')
plt.ylabel('Price in Cr', fontsize = 16, fontweight = 'bold')
plt.title('Top 10 Expensive Players in IPL', fontsize = 22, fontweight = 'bold')
plt.show()
